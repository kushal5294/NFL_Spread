# %%
import pandas as pd

combined_df = pd.DataFrame()

file_names = ['AFC.csv', 'NFC.csv' ] 
for file_name in file_names:
        data = pd.read_csv(file_name)
        combined_df = pd.concat([data, combined_df], axis=0)
   
print(combined_df)
combined_df.fillna(0.0, inplace=True)
combined_df['Tm'] = combined_df['Tm'].str.replace('*', '')
combined_df['Tm'] = combined_df['Tm'].str.replace('+', '')

combined_df.to_csv('2023NFLDATA_overall.csv', index=False)
# Out:
#                        Tm  W  L   W-L%   PF   PA   PD   MoV  SoS   SRS  OSRS  \
# 0    Philadelphia Eagles*  8  1  0.889  252  195   57   6.3 -1.5   4.9   5.1
# 1         Dallas Cowboys+  6  3  0.667  269  165  104  11.6 -2.7   8.8   8.0
# 2   Washington Commanders  4  6  0.400  217  274  -57  -5.7 -3.1  -8.8  -1.8
# 3         New York Giants  2  8  0.200  118  266 -148 -14.8  1.4 -13.4 -10.7
# 4          Detroit Lions*  7  2  0.778  241  203   38   4.2  0.4   4.6   6.6
# 5      Minnesota Vikings+  6  4  0.600  233  209   24   2.4  0.7   3.1   2.4
# 6       Green Bay Packers  3  6  0.333  179  182   -3  -0.3 -1.6  -1.9  -2.9
# 7           Chicago Bears  3  7  0.300  204  255  -51  -5.1 -1.9  -7.0  -1.9
# 8     New Orleans Saints*  5  5  0.500  214  198   16   1.6 -1.0   0.6  -0.1
# 9    Tampa Bay Buccaneers  4  5  0.444  178  173    5   0.6  0.8   1.4  -2.4
# 10        Atlanta Falcons  4  6  0.400  189  217  -28  -2.8 -1.0  -3.8  -3.3
# 11      Carolina Panthers  1  8  0.111  153  242  -89  -9.9  0.8  -9.1  -6.5
# 12   San Francisco 49ers*  6  3  0.667  252  143  109  12.1  0.8  13.0   7.1
# 13      Seattle Seahawks*  6  3  0.667  200  201   -1  -0.1 -1.4  -1.5   0.0
# 14       Los Angeles Rams  3  6  0.333  178  204  -26  -2.9  2.4  -0.5  -1.5
# 15      Arizona Cardinals  2  8  0.200  176  263  -87  -8.7  1.8  -6.9  -3.2
# 0         Miami Dolphins*  6  3  0.667  285  225   60   6.7 -3.2   3.4   9.4
# 1           Buffalo Bills  5  5  0.500  262  184   78   7.8 -4.5   3.3   2.8
# 2           New York Jets  4  5  0.444  144  172  -28  -3.1 -1.4  -4.6  -6.2
# 3    New England Patriots  2  8  0.200  141  238  -97  -9.7  0.0  -9.7  -9.9
# 4       Baltimore Ravens*  7  3  0.700  270  157  113  11.3  2.1  13.4   5.8
# 5    Pittsburgh Steelers+  6  3  0.667  156  182  -26  -2.9  2.9   0.0  -2.1
# 6       Cleveland Browns+  6  3  0.667  214  170   44   4.9  3.6   8.5   4.0
# 7      Cincinnati Bengals  5  4  0.556  182  192  -10  -1.1  3.4   2.3   0.3
# 8   Jacksonville Jaguars*  6  3  0.667  196  190    6   0.7  2.5   3.1   0.9
# 9         Houston Texans+  5  4  0.556  217  192   25   2.8  1.2   4.0   3.8
# 10     Indianapolis Colts  5  5  0.500  242  248   -6  -0.6  1.4   0.8   4.4
# 11       Tennessee Titans  3  6  0.333  154  180  -26  -2.9  3.2   0.3  -2.8
# 12    Kansas City Chiefs*  7  2  0.778  208  143   65   7.2 -1.2   6.0  -1.4
# 13      Las Vegas Raiders  5  5  0.500  172  205  -33  -3.3 -3.3  -6.6  -5.8
# 14   Los Angeles Chargers  4  5  0.444  239  215   24   2.7  0.6   3.3   4.6
# 15         Denver Broncos  4  5  0.444  196  248  -52  -5.8 -1.4  -7.2  -0.2
#
#     DSRS
# 0   -0.2
# 1    0.8
# 2   -7.0
# 3   -2.7
# 4   -2.0
# 5    0.7
# 6    1.0
# 7   -5.2
# 8    0.7
# 9    3.8
# 10  -0.5
# 11  -2.6
# 12   5.8
# 13  -1.5
# 14   1.1
# 15  -3.7
# 0   -6.0
# 1    0.5
# 2    1.7
# 3    0.2
# 4    7.6
# 5    2.1
# 6    4.4
# 7    2.1
# 8    2.2
# 9    0.2
# 10  -3.6
# 11   3.2
# 12   7.5
# 13  -0.7
# 14  -1.3
# 15  -7.0
